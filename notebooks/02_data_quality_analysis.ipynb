# %% [markdown]
# ## Analysis of dirty dataset

# %%
dirty_customers = pd.read_csv(
    "../data/raw/customers_dirty.csv"
)

# %%
dirty_customers.shape
# Out:
# (502, 7)

# %%
dirty_customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    502 non-null    str
#  1   customer_name  502 non-null    str
#  2   city           501 non-null    str
#  3   state          502 non-null    str
#  4   customer_type  501 non-null    str
#  5   credit_limit   502 non-null    int64
#  6   created_at     502 non-null    str
# dtypes: int64(1), str(6)
# memory usage: 27.6 KB

# %%
dirty_customers.isnull().sum()
# Out:
# customer_id      0
# customer_name    0
# city             1
# state            0
# customer_type    1
# credit_limit     0
# created_at       0
# dtype: int64

# %%
dirty_customers.duplicated().sum()
# Out:
# np.int64(2)

# %%
dirty_customers.dtypes
# Out:
# customer_id        str
# customer_name      str
# city               str
# state              str
# customer_type      str
# credit_limit     int64
# created_at         str
# dtype: object

# %%
dirty_customers["credit_limit"].describe()
# Out:
# count       502.000000
# mean     169870.517928
# std      155126.415410
# min      -50000.000000
# 25%       50000.000000
# 50%      100000.000000
# 75%      250000.000000
# max      500000.000000
# Name: credit_limit, dtype: float64

# %%
dirty_customers[
    dirty_customers["credit_limit"] <= 0
]
# Out:
#    customer_id      customer_name       city          state customer_type  \
# 50      C00051      Mohit Traders  Ghaziabad  Uttar Pradesh   Distributor
# 51      C00052  Rahul Enterprises      Hapur  Uttar Pradesh      Retailer
#
#     credit_limit  created_at
# 50        -50000  2024-05-27
# 51             0  2022-06-10

# %%
pd.to_datetime(
    dirty_customers["created_at"],
    errors="coerce"
).isna().sum()
# Out:
# np.int64(1)

# %%
dirty_customers[
    dirty_customers["customer_name"] !=
    dirty_customers["customer_name"].str.strip()
]
# Out:
#    customer_id   customer_name   city          state customer_type  \
# 40      C00041    Amit Traders  Hapur  Uttar Pradesh    Wholesaler
#
#     credit_limit  created_at
# 40         75000  2023-10-22

# %%
dirty_customers[
    dirty_customers["customer_name"] !=
    dirty_customers["customer_name"].str.title()
]
# Out:
#    customer_id customer_name   city          state customer_type  \
# 41      C00042   ARJUN STORE  Noida  Uttar Pradesh      Retailer
#
#     credit_limit  created_at
# 41         75000  2026-03-15

# %%
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
