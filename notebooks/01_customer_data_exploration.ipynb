# %% [markdown]
# ## First Analysis

# %%
import pandas as pd
customers = pd.read_csv("../data/raw/customers.csv")
customers.head()
# Out:
#   customer_id        customer_name    city          state customer_type  \
# 0      C00001  Manish Distributors    Agra  Uttar Pradesh      Retailer
# 1      C00002    Rohit Wholesalers    Agra  Uttar Pradesh      Retailer
# 2      C00003    Vikas Enterprises    Agra  Uttar Pradesh    Wholesaler
# 3      C00004           Arjun Mart  Meerut  Uttar Pradesh      Retailer
# 4      C00005        Arjun Traders  Meerut  Uttar Pradesh      Retailer
#
#    credit_limit  created_at
# 0        500000  2022-05-02
# 1         75000  2026-08-13
# 2        250000  2023-01-21
# 3        250000  2022-09-10
# 4        500000  2026-02-08

# %%
customers.shape
# Out:
# (500, 7)

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    500 non-null    str
#  1   customer_name  500 non-null    str
#  2   city           500 non-null    str
#  3   state          500 non-null    str
#  4   customer_type  500 non-null    str
#  5   credit_limit   500 non-null    int64
#  6   created_at     500 non-null    str
# dtypes: int64(1), str(6)
# memory usage: 27.5 KB

# %%
customers.describe
# Out:
# <bound method NDFrame.describe of     customer_id        customer_name         city          state  \
# 0        C00001  Manish Distributors         Agra  Uttar Pradesh
# 1        C00002    Rohit Wholesalers         Agra  Uttar Pradesh
# 2        C00003    Vikas Enterprises         Agra  Uttar Pradesh
# 3        C00004           Arjun Mart       Meerut  Uttar Pradesh
# 4        C00005        Arjun Traders       Meerut  Uttar Pradesh
# ..          ...                  ...          ...            ...
# 495      C00496         Suresh Store        Noida  Uttar Pradesh
# 496      C00497   Vikas Distributors        Delhi          Delhi
# 497      C00498    Nitin Wholesalers        Delhi          Delhi
# 498      C00499   Suresh Wholesalers  Bulandshahr  Uttar Pradesh
# 499      C00500        Suresh Agency      Lucknow  Uttar Pradesh
#
#     customer_type  credit_limit  created_at
# 0        Retailer        500000  2022-05-02
# 1        Retailer         75000  2026-08-13
# ...

# %%
customers.isnull().sum()
# Out:
# customer_id      0
# customer_name    0
# city             0
# state            0
# customer_type    0
# credit_limit     0
# created_at       0
# dtype: int64

# %%
customers["customer_type"].value_counts()
# Out:
# customer_type
# Retailer       296
# Wholesaler     155
# Distributor     49
# Name: count, dtype: int64

# %%
customers["credit_limit"].describe()
# Out:
# count       500.000000
# mean     170250.000000
# std      154989.454357
# min       25000.000000
# 25%       50000.000000
# 50%      100000.000000
# 75%      250000.000000
# max      500000.000000
# Name: credit_limit, dtype: float64
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
